# %% [markdown]
# # 01: Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Data Import

# %%
path = r'C:\Users\14239\Downloads\Instacart Basket Analysis'

# %%
# Import orders_products_combined

orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
orders_products_combined.shape
# Out:
# (32434489, 14)

# %%
# Import df_prods

df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
orders_products_combined.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id eval_set  \
# 0           0             0   2539329        1    prior
# 1           0             0   2539329        1    prior
# 2           0             0   2539329        1    prior
# 3           0             0   2539329        1    prior
# 4           0             0   2539329        1    prior
#
#    user_cumulative_order_number  orders_day_of_week  order_hour_of_day  \
# 0                             1                   2                  8
# 1                             1                   2                  8
# 2                             1                   2                  8
# 3                             1                   2                  8
# 4                             1                   2                  8
#
#    days_since_prior_order  first_order  product_id  add_to_cart_order  \
# 0                     NaN         True         196                  1
# ...

# %%
# Rename column _merge to _merge1 to allow for needed merge

df_prods.rename(columns = {'_merge' : '_merge1'}, inplace = True)

# %%
orders_products_combined.rename(columns = {'_merge' : '_merge1'}, inplace = True)

# %%
orders_products_combined.drop(columns = ['Unnamed: 0'])
# Out:
#           Unnamed: 0.1  order_id  user_id eval_set  \
# 0                    0   2539329        1    prior
# 1                    0   2539329        1    prior
# 2                    0   2539329        1    prior
# 3                    0   2539329        1    prior
# 4                    0   2539329        1    prior
# ...                ...       ...      ...      ...
# 32434484       3421081   2977660   206209    prior
# 32434485       3421081   2977660   206209    prior
# 32434486       3421081   2977660   206209    prior
# 32434487       3421081   2977660   206209    prior
# 32434488       3421081   2977660   206209    prior
#
#           user_cumulative_order_number  orders_day_of_week  order_hour_of_day  \
# 0                                    1                   2                  8
# 1                                    1                   2                  8
# 2                                    1                   2                  8
# ...

# %%
orders_products_combined.drop(columns = ['Unnamed: 0.1'])
# Out:
#           Unnamed: 0  order_id  user_id eval_set  \
# 0                  0   2539329        1    prior
# 1                  0   2539329        1    prior
# 2                  0   2539329        1    prior
# 3                  0   2539329        1    prior
# 4                  0   2539329        1    prior
# ...              ...       ...      ...      ...
# 32434484     3421081   2977660   206209    prior
# 32434485     3421081   2977660   206209    prior
# 32434486     3421081   2977660   206209    prior
# 32434487     3421081   2977660   206209    prior
# 32434488     3421081   2977660   206209    prior
#
#           user_cumulative_order_number  orders_day_of_week  order_hour_of_day  \
# 0                                    1                   2                  8
# 1                                    1                   2                  8
# 2                                    1                   2                  8
# ...

# %%
# Drop unneeded columns Unnamed: 0, Unnamed: 01, and eval_set for new df orders_products_combined_1

orders_products_combined_1 = orders_products_combined.drop(columns = ['Unnamed: 0' , 'Unnamed: 0.1' , 'eval_set'])

# %%
orders_products_combined_1.head()
# Out:
#    order_id  user_id  user_cumulative_order_number  orders_day_of_week  \
# 0   2539329        1                             1                   2
# 1   2539329        1                             1                   2
# 2   2539329        1                             1                   2
# 3   2539329        1                             1                   2
# 4   2539329        1                             1                   2
#
#    order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 0                  8                     NaN         True         196
# 1                  8                     NaN         True       14084
# 2                  8                     NaN         True       12427
# 3                  8                     NaN         True       26088
# 4                  8                     NaN         True       26405
#
#    add_to_cart_order  reordered _merge1
# 0                  1          0    both
# ...

# %%
orders_products_combined_1.shape
# Out:
# (32434489, 11)

# %%
# Merge dataframes orders_products_ combined_1 and product_id

orders_products_merged = orders_products_combined_1.merge(df_prods, on = ['product_id'], how = 'left',indicator = True)

# %%
# Confirm results of merge

orders_products_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only        30200
# right_only           0
# Name: _merge, dtype: int64

# %%
orders_products_merged.shape
# Out:
# (32435059, 17)

# %%
# Export orders_products_merged

orders_products_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
