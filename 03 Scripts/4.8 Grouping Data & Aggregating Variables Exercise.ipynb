# %% [markdown]
# # 01: Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Data Import

# %%
path = r'C:\Users\14239\Downloads\Instacart Basket Analysis'

# %%
# Import orders_products_merged_2

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_2.pkl'))

# %%
# Create a subset

df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 21)

# %%
df.head()
# Out:
#    order_id  user_id  user_cumulative_order_number  orders_day_of_week  \
# 0   2539329        1                             1                   2
# 1   2539329        1                             1                   2
# 2   2539329        1                             1                   2
# 3   2539329        1                             1                   2
# 4   2539329        1                             1                   2
#
#    order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 0                  8                     NaN         True         196
# 1                  8                     NaN         True       14084
# 2                  8                     NaN         True       12427
# 3                  8                     NaN         True       26088
# 4                  8                     NaN         True       26405
#
#    add_to_cart_order  reordered  ... Unnamed: 0  \
# 0                  1          0  ...      195.0
# ...

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'user_cumulative_order_number': ['mean']})
# Out:
#               user_cumulative_order_number
#                                       mean
# department_id
# 1.0                              14.792915
# 2.0                              17.091743
# 3.0                              17.919589
# 4.0                              17.891973
# 5.0                              15.214270
# 6.0                              15.382228
# 7.0                              17.699986
# 8.0                              16.485269
# 9.0                              15.965921
# 10.0                             20.091818
# 11.0                             16.485395
# 12.0                             15.615845
# 13.0                             16.485052
# 14.0                             17.523474
# 15.0                             15.690354
# 16.0                             18.014342
# 17.0                             16.155822
# 18.0                             19.606536
# 19.0                             17.630236
# ...

# %%
df.groupby('department_id')['user_cumulative_order_number'].mean()
# Out:
# department_id
# 1.0     14.792915
# 2.0     17.091743
# 3.0     17.919589
# 4.0     17.891973
# 5.0     15.214270
# 6.0     15.382228
# 7.0     17.699986
# 8.0     16.485269
# 9.0     15.965921
# 10.0    20.091818
# 11.0    16.485395
# 12.0    15.615845
# 13.0    16.485052
# 14.0    17.523474
# 15.0    15.690354
# 16.0    18.014342
# 17.0    16.155822
# 18.0    19.606536
# 19.0    17.630236
# 20.0    17.138204
# 21.0    21.996844
# Name: user_cumulative_order_number, dtype: float64

# %%
df.groupby('department_id').agg({'user_cumulative_order_number': ['mean', 'min', 'max']})
# Out:
#               user_cumulative_order_number
#                                       mean min max
# department_id
# 1.0                              14.792915   1  99
# 2.0                              17.091743   1  98
# 3.0                              17.919589   1  99
# 4.0                              17.891973   1  99
# 5.0                              15.214270   1  99
# 6.0                              15.382228   1  99
# 7.0                              17.699986   1  99
# 8.0                              16.485269   1  91
# 9.0                              15.965921   1  99
# 10.0                             20.091818   1  99
# 11.0                             16.485395   1  99
# 12.0                             15.615845   1  99
# 13.0                             16.485052   1  99
# 14.0                             17.523474   1  99
# 15.0                             15.690354   1  99
# 16.0                             18.014342   1  99
# ...

# %% [markdown]
# 2. Create a loyalty flag using loc

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['user_cumulative_order_number'].transform(np.max)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  user_cumulative_order_number  orders_day_of_week  \
# 0    2539329        1                             1                   2
# 1    2539329        1                             1                   2
# 2    2539329        1                             1                   2
# 3    2539329        1                             1                   2
# 4    2539329        1                             1                   2
# 5    2398795        1                             2                   3
# 6    2398795        1                             2                   3
# 7    2398795        1                             2                   3
# 8    2398795        1                             2                   3
# 9    2398795        1                             2                   3
# 10   2398795        1                             2                   3
# 11    473747        1                             3                   3
# ...

# %%
ords_prods_merge.tail()
# Out:
#           order_id  user_id  user_cumulative_order_number  orders_day_of_week  \
# 32435054   2977660   206209                            13                   1
# 32435055   2977660   206209                            13                   1
# 32435056   2977660   206209                            13                   1
# 32435057   2977660   206209                            13                   1
# 32435058   2977660   206209                            13                   1
#
#           order_hour_of_day  days_since_prior_order  first_order  product_id  \
# 32435054                 12                     7.0        False       14197
# 32435055                 12                     7.0        False       38730
# 32435056                 12                     7.0        False       31477
# 32435057                 12                     7.0        False        6567
# 32435058                 12                     7.0        False       22920
#
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15891507
# Loyal customer      10294027
# New customer         6249525
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'user_cumulative_order_number']].tail(60)
# Out:
#           user_id      loyalty_flag  user_cumulative_order_number
# 32434999   206209  Regular customer                             8
# 32435000   206209  Regular customer                             8
# 32435001   206209  Regular customer                             8
# 32435002   206209  Regular customer                             8
# 32435003   206209  Regular customer                             8
# 32435004   206209  Regular customer                             8
# 32435005   206209  Regular customer                             8
# 32435006   206209  Regular customer                             8
# 32435007   206209  Regular customer                             8
# 32435008   206209  Regular customer                             8
# 32435009   206209  Regular customer                             8
# 32435010   206209  Regular customer                             9
# 32435011   206209  Regular customer                             9
# ...
